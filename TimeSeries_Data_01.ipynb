# %%
# Time Series
# What is time series data? if your data is collected based on time frequency.
# Day, Month, Years
# Finance, Retail, (Weather Forecasting -> time -> pulse, locations)
# Share Market data analysis

# %%
import pandas as pd

# %%
appl=pd.read_csv(r'C:\Users\HP P DTS\Desktop\Python Classes\DataSet\AAPL.csv',parse_dates=['Date'],index_col='Date')

# %%
appl.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-20  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
#
#               Volume
# Date
# 2019-02-14  21835700
# 2019-02-15  24626800
# 2019-02-19  18972800
# 2019-02-20  26114400
# 2019-02-21  17249700

# %%
type(appl.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
appl_copy=appl.copy()

# %%
appl_copy.set_index('Date',inplace=True)

# %%
appl_copy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-20  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-22  171.580002  173.000000  171.380005  172.970001  170.735229
# 2019-02-25  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-26  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-27  173.210007  175.000000  172.729996  174.869995  172.610687
# 2019-02-28  174.320007  174.910004  172.919998  173.149994  170.912918
# 2019-03-01  174.279999  175.149994  172.889999  174.970001  172.709381
# 2019-03-04  175.690002  177.750000  173.970001  175.850006  173.578033
# ...

# %%
import matplotlib.pyplot as plt

# %%
appl_copy.Close.plot()

# %%
appl_copy['2019']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-20  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-22  171.580002  173.000000  171.380005  172.970001  170.735229
# 2019-02-25  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-26  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-27  173.210007  175.000000  172.729996  174.869995  172.610687
# 2019-02-28  174.320007  174.910004  172.919998  173.149994  170.912918
# 2019-03-01  174.279999  175.149994  172.889999  174.970001  172.709381
# 2019-03-04  175.690002  177.750000  173.970001  175.850006  173.578033
# ...

# %%
appl_copy['2019-2']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-20  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-22  171.580002  173.000000  171.380005  172.970001  170.735229
# 2019-02-25  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-26  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-27  173.210007  175.000000  172.729996  174.869995  172.610687
# 2019-02-28  174.320007  174.910004  172.919998  173.149994  170.912918
#
#               Volume
# Date
# 2019-02-14  21835700
# 2019-02-15  24626800
# 2019-02-19  18972800
# 2019-02-20  26114400
# 2019-02-21  17249700
# 2019-02-22  18913200
# ...

# %%
appl_copy['2019-2':'2019-6']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-20  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-22  171.580002  173.000000  171.380005  172.970001  170.735229
# 2019-02-25  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-26  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-27  173.210007  175.000000  172.729996  174.869995  172.610687
# 2019-02-28  174.320007  174.910004  172.919998  173.149994  170.912918
# 2019-03-01  174.279999  175.149994  172.889999  174.970001  172.709381
# 2019-03-04  175.690002  177.750000  173.970001  175.850006  173.578033
# ...

# %%
appl_copy['2019-2':'2019-6'][['Close','Open']]
# Out:
#                  Close        Open
# Date
# 2019-02-14  170.800003  169.710007
# 2019-02-15  170.419998  171.250000
# 2019-02-19  170.929993  169.710007
# 2019-02-20  172.029999  171.190002
# 2019-02-21  171.059998  171.800003
# 2019-02-22  172.970001  171.580002
# 2019-02-25  174.229996  174.160004
# 2019-02-26  174.330002  173.710007
# 2019-02-27  174.869995  173.210007
# 2019-02-28  173.149994  174.320007
# 2019-03-01  174.970001  174.279999
# 2019-03-04  175.850006  175.690002
# 2019-03-05  175.529999  175.940002
# 2019-03-06  174.520004  174.669998
# 2019-03-07  172.500000  173.869995
# 2019-03-08  172.910004  170.320007
# 2019-03-11  178.899994  175.490005
# 2019-03-12  180.910004  180.000000
# 2019-03-13  181.710007  182.250000
# 2019-03-14  183.729996  183.899994
# 2019-03-15  186.119995  184.850006
# 2019-03-18  188.020004  185.800003
# 2019-03-19  186.529999  188.350006
# 2019-03-20  188.160004  186.229996
# 2019-03-21  195.089996  190.020004
# ...

# %%
appl_copy['2019-2':'2019-6':2]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-19  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-21  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-25  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-27  173.210007  175.000000  172.729996  174.869995  172.610687
# 2019-03-01  174.279999  175.149994  172.889999  174.970001  172.709381
# 2019-03-05  175.940002  176.000000  174.539993  175.529999  173.262161
# 2019-03-07  173.869995  174.440002  172.020004  172.500000  170.271317
# 2019-03-11  175.490005  179.119995  175.350006  178.899994  176.588608
# 2019-03-13  182.250000  183.300003  180.919998  181.710007  179.362320
# 2019-03-15  184.850006  187.330002  183.740005  186.119995  183.715332
# 2019-03-19  188.350006  188.990005  185.919998  186.529999  184.120056
# ...

# %%
# Resample 
appl_copy['Close'].resample('M').mean()
# Out:
# Date
# 2019-02-28    172.478998
# 2019-03-31    183.293810
# 2019-04-30    200.516191
# 2019-05-31    191.273637
# 2019-06-30    192.969000
# 2019-07-31    205.216364
# 2019-08-31    204.957728
# 2019-09-30    217.994999
# 2019-10-31    235.286521
# 2019-11-30    262.520503
# 2019-12-31    276.525710
# 2020-01-31    311.916191
# 2020-02-29    321.263840
# Freq: M, Name: Close, dtype: float64

# %%
appl_copy['Close'].resample('W').mean()
# Out:
# Date
# 2019-02-17    170.610001
# 2019-02-24    171.747498
# 2019-03-03    174.309998
# 2019-03-10    174.262003
# 2019-03-17    182.273999
# 2019-03-24    189.770001
# 2019-03-31    188.533999
# 2019-04-07    194.660003
# 2019-04-14    199.607999
# 2019-04-21    201.367501
# 2019-04-28    205.750000
# 2019-05-05    207.339999
# 2019-05-12    202.427997
# 2019-05-19    188.876001
# 2019-05-26    182.220001
# 2019-06-02    177.245003
# 2019-06-09    182.169998
# 2019-06-16    193.694000
# 2019-06-23    197.689999
# 2019-06-30    198.322003
# 2019-07-07    203.230000
# 2019-07-14    201.908002
# 2019-07-21    204.262003
# 2019-07-28    207.898001
# 2019-08-04    208.789996
# 2019-08-11    198.759997
# 2019-08-18    204.088000
# 2019-08-25    209.690002
# 2019-09-01    206.786002
# 2019-09-08    210.357498
# 2019-09-15    219.259997
# 2019-09-22    220.412000
# 2019-09-29    219.228000
# 2019-10-06    223.070001
# 2019-10-13    228.957999
# 2019-10-20    235.450000
# ...

# %%
appl_copy['Close'].resample('M').mean().plot(label='Close')
appl_copy['Open'].resample('M').mean().plot(label='Open')
plt.legend()

# %%
appl_copy['Close'].resample('M').mean().plot(kind='bar')

# %%
appl_copy['Close'].resample('M').max()
# Out:
# Date
# 2019-02-28    174.869995
# 2019-03-31    195.089996
# 2019-04-30    207.479996
# 2019-05-31    211.750000
# 2019-06-30    199.800003
# 2019-07-31    213.039993
# 2019-08-31    212.639999
# 2019-09-30    223.970001
# 2019-10-31    249.050003
# 2019-11-30    267.839996
# 2019-12-31    293.649994
# 2020-01-31    324.339996
# 2020-02-29    327.200012
# Freq: M, Name: Close, dtype: float64

# %%
date_rng=pd.date_range(start='02-01-2019',end='12-31-2019')

# %%
date_rng
# Out:
# DatetimeIndex(['2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04',
#                '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08',
#                '2019-02-09', '2019-02-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=334, freq='D')

# %%
date_rng=pd.date_range(start='02-01-2019',end='12-31-2019',freq='D')
date_rng
# Out:
# DatetimeIndex(['2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04',
#                '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08',
#                '2019-02-09', '2019-02-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=334, freq='D')

# %%
bus_date_rng=pd.date_range(start='02-01-2019',end='12-31-2019',freq='B')
bus_date_rng
# Out:
# DatetimeIndex(['2019-02-01', '2019-02-04', '2019-02-05', '2019-02-06',
#                '2019-02-07', '2019-02-08', '2019-02-11', '2019-02-12',
#                '2019-02-13', '2019-02-14',
#                ...
#                '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#                '2019-12-24', '2019-12-25', '2019-12-26', '2019-12-27',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=238, freq='B')

# %%
mon_date_rng=pd.date_range(start='02-01-2019',end='12-31-2019',freq='M')
mon_date_rng
# Out:
# DatetimeIndex(['2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31',
#                '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
#                '2019-10-31', '2019-11-30', '2019-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
hour_date_rng=pd.date_range(start='02-01-2019',end='02-03-2019',freq='H')
hour_date_rng
# Out:
# DatetimeIndex(['2019-02-01 00:00:00', '2019-02-01 01:00:00',
#                '2019-02-01 02:00:00', '2019-02-01 03:00:00',
#                '2019-02-01 04:00:00', '2019-02-01 05:00:00',
#                '2019-02-01 06:00:00', '2019-02-01 07:00:00',
#                '2019-02-01 08:00:00', '2019-02-01 09:00:00',
#                '2019-02-01 10:00:00', '2019-02-01 11:00:00',
#                '2019-02-01 12:00:00', '2019-02-01 13:00:00',
#                '2019-02-01 14:00:00', '2019-02-01 15:00:00',
#                '2019-02-01 16:00:00', '2019-02-01 17:00:00',
#                '2019-02-01 18:00:00', '2019-02-01 19:00:00',
#                '2019-02-01 20:00:00', '2019-02-01 21:00:00',
#                '2019-02-01 22:00:00', '2019-02-01 23:00:00',
#                '2019-02-02 00:00:00', '2019-02-02 01:00:00',
#                '2019-02-02 02:00:00', '2019-02-02 03:00:00',
#                '2019-02-02 04:00:00', '2019-02-02 05:00:00',
# ...

# %%
appl_copy.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02-10  314.179993  321.549988  313.850006  321.549988  321.549988
# 2020-02-11  323.600006  323.899994  318.709991  319.609985  319.609985
# 2020-02-12  321.470001  327.220001  321.470001  327.200012  327.200012
# 2020-02-13  324.190002  326.220001  323.350006  324.869995  324.869995
# 2020-02-14  324.739990  325.980011  322.853699  325.208405  325.208405
#
#               Volume
# Date
# 2020-02-10  27337200
# 2020-02-11  23580800
# 2020-02-12  28432600
# 2020-02-13  23625500
# 2020-02-14   6072676

# %%
appl_01=pd.read_csv(r'C:\Users\HP P DTS\Desktop\Python Classes\DataSet\AAPL_01.csv')

# %%
appl_01.head()
# Out:
#          Open        High         Low       Close   Adj Close    Volume
# 0  169.710007  171.259995  169.380005  170.800003  168.593292  21835700
# 1  171.250000  171.699997  169.750000  170.419998  168.218201  24626800
# 2  169.710007  171.440002  169.490005  170.929993  168.721588  18972800
# 3  171.190002  173.320007  170.990005  172.029999  169.807388  26114400
# 4  171.800003  172.369995  170.300003  171.059998  168.849930  17249700

# %%
dt_rng=pd.date_range(start='02-14-2019',end='02-14-2020',freq='B')

# %%
dt_rng=pd.date_range(start='02-14-2019',periods=253,freq='B')

# %%
appl_01.set_index(dt_rng,inplace=True)

# %%
appl_01.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-18  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-19  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-20  171.800003  172.369995  170.300003  171.059998  168.849930
#
#               Volume
# 2019-02-14  21835700
# 2019-02-15  24626800
# 2019-02-18  18972800
# 2019-02-19  26114400
# 2019-02-20  17249700

# %%
appl_01.asfreq(freq='D',method="bfill")
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-02-14  169.710007  171.259995  169.380005  170.800003  168.593292
# 2019-02-15  171.250000  171.699997  169.750000  170.419998  168.218201
# 2019-02-16  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-17  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-18  169.710007  171.440002  169.490005  170.929993  168.721588
# 2019-02-19  171.190002  173.320007  170.990005  172.029999  169.807388
# 2019-02-20  171.800003  172.369995  170.300003  171.059998  168.849930
# 2019-02-21  171.580002  173.000000  171.380005  172.970001  170.735229
# 2019-02-22  174.160004  175.869995  173.949997  174.229996  171.978958
# 2019-02-23  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-24  173.710007  175.300003  173.169998  174.330002  172.077667
# 2019-02-25  173.710007  175.300003  173.169998  174.330002  172.077667
# ...
